# %%
#print square of every element in list
#list=[<output var> <for loop>]
lst=[i*i for i in range(2,21)]
print(lst)
# Out:
# [4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400]

# %%
#find average marks
summ=0
marks=[45,76,89,53,67,90,49,33,99]
[summ:=summ+i for i in marks]
#[<output> <for loop>]
summ/len(marks)
# Out:
# 66.77777777777777

# %%
#odd even
even=[]
odd=[]
[f'even:{i}' if i%2==0 else f'odd: {i}' for i in range(1,10)]
#[<output> <if condition> <else condition> <for loop]
# Out:
# ['odd: 1',
#  'even:2',
#  'odd: 3',
#  'even:4',
#  'odd: 5',
#  'even:6',
#  'odd: 7',
#  'even:8',
#  'odd: 9']

# %%
#convert string elements into uppercase
lst=['apple','banana','mango']
lst1=[i.upper() for i in lst]
lst1
# Out:
# ['APPLE', 'BANANA', 'MANGO']

# %%
#print cube of 1 to 20 numbers
lst=[i*i*i for i in range (1,21)]
print(lst)
# Out:
# [1, 8, 27, 64, 125, 216, 343, 512, 729, 1000, 1331, 1728, 2197, 2744, 3375, 4096, 4913, 5832, 6859, 8000]

# %%
#extract vowels from string into a list
strr='Hey,welcome to python programming world'
lst=[i for i in strr if i in 'aeiou']
lst
# Out:
# ['e', 'e', 'o', 'e', 'o', 'o', 'o', 'a', 'i', 'o']

# %%
#create a list containing the length of each word
words=['apple','banana','cherry']
l1=[len(i) for i in words]
l1
# Out:
# [5, 6, 6]

# %%
#create a list containing only words longer than 3 characters
wrd=['cat','elephant','dog','giraffe']
lst=[i for i in wrd if len(i)==3 ]
lst
# Out:
# ['cat', 'dog']

# %%
#create a list containing only positive numbers
l1=[9,3,-1,-2,-7,7,5]
l2=[i for i in l1 if i>0]
l2
# Out:
# [9, 3, 7, 5]

# %%
#append string into list
text='python is fun'
lst=[i for i in text]
lst
# Out:
# ['p', 'y', 't', 'h', 'o', 'n', ' ', 'i', 's', ' ', 'f', 'u', 'n']
