# %%
#wap to add two numbers 
n1=int(input('enter number'))
n2=int(input('enter number'))
add=n1+n2
print(f'addition of {n1} and {n2} is {add}')
# Out:
# enter number 2
# enter number 3
# addition of 2 and 3 is 5

# %%
#wap to find square of the number
num=int(input('enter number to find square'))
sqr=num*num
print(f'square of {num} is {sqr}')
# Out:
# enter number to find square 2
# square of 2 is 4

# %%
#wap to find cube of the number
num1=int(input('enter number to find square'))
cube=num1*num1*num1
print(f'cube of {num1} is {cube}')
# Out:
# enter number to find square 3
# cube of 3 is 27

# %%
#wap to find area of circle
radius=eval(input('enter radius'))
pi=3.14
area=pi*radius*radius
print(f'area of circle is {area}')
# Out:
# enter radius 5
# area of circle is 78.5

# %%
#square root
num=int(input('enter number to find square'))
sqrt=num*0.5
print(f'square of {num} is {sqrt}')
# Out:
# enter number to find square 8
# square of 8 is 4.0

# %%
#cube root
num=int(input('enter number to find square'))
sqrt=num*1/3
print(f'square of {num} is {sqrt}')
# Out:
# enter number to find square 9
# square of 9 is 3.0

# %%
#area of triangle
ht=int(input('enter height'))
bs=int(input('enter base'))
area_of_triangle=0.5*bs*ht
print(f'area of triangle is {area_of_triangle}')
# Out:
# enter height 6
# enter base 3
# area of triangle is 9.0

# %%
#area of square
side=int(input('enter side'))
area_of_square=side**2 #side*side
print(f'area of square is {area_of_square}')
# Out:
# enter side 5
# area of square is 25

# %%
#wap to find average of three numbers
n1=int(input(''))
n2=int(input(''))
n3=int(input(''))
avg=n1+n2+n3/3
print(f'average of {n1} {n2} and {n3} is {avg}')
# Out:
#  5
#  6
#  7
# average of 5 6 and 7 is 13.333333333333334

# %%
#multiplication table of user given number
num=int(input('enter number for table'))
for i in range(1,11):
    print(f'{num} X {i} = {num*i}')
# Out:
# enter number for table 7
# 7 X 1 = 7
# 7 X 2 = 14
# 7 X 3 = 21
# 7 X 4 = 28
# 7 X 5 = 35
# 7 X 6 = 42
# 7 X 7 = 49
# 7 X 8 = 56
# 7 X 9 = 63
# 7 X 10 = 70
